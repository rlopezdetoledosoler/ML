# %%
# Load the full dataset of Chicago Crime
import pandas as pd
from pandas import DataFrame
import google
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="Master-02851e90403f.json"

# Imports the Google Cloud client library
from google.cloud import storage

# Instantiates a client
storage_client = storage.Client.from_service_account_json('Master-02851e90403f.json')

# The name for the new bucket
bucket_name = "bi-dataset-chicago"

from google.cloud import bigquery

client = bigquery.Client()
dataset_ref = client.dataset('chicago_crime', project='bigquery-public-data')
chicago_dataset = client.get_dataset(dataset_ref)

chicago_table = client.get_table(chicago_dataset.table('crime'))

# SQL query
# We reduce the total data to only 2019 non-domestic events, which is the target we want to study
query="""SELECT * FROM `bigquery-public-data.chicago_crime.crime` WHERE domestic=FALSE and year = 2019"""
# Set up the query
query_job = client.query(query)
#API request - run the query, and return a pandas DataFrame
chicago_crime = query_job.to_dataframe()

#Export to .csv
chicago_crime.to_csv('chicago_crime.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f4594bf2e541> in <module>
#      29 query_job = client.query(query)
#      30 #API request - run the query, and return a pandas DataFrame
# ---> 31 chicago_crime = query_job.to_dataframe()
#      32
#      33 #Export to .csv
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type)
#    3247             ValueError: If the `pandas` library cannot be imported.
#    3248         """
# -> 3249         return self.result().to_dataframe(
#    3250             bqstorage_client=bqstorage_client,
#    3251             dtypes=dtypes,
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, timeout, page_size, retry, max_results)
#    3122         """
#    3123         try:
# -> 3124             super(QueryJob, self).result(timeout=timeout)
#    3125
#    3126             # Return an iterator instead of returning the job.
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     777             self._begin(retry=retry)
#     778         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 779         return super(_AsyncJob, self).result(timeout=timeout)
#     780
#     781     def cancelled(self):
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in result(self, timeout)
#     120                 the timeout is reached before the operation completes.
#     121         """
# --> 122         self._blocking_poll(timeout=timeout)
#     123
#     124         if self._exception is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in _blocking_poll(self, timeout)
#    3035     def _blocking_poll(self, timeout=None):
#    3036         self._done_timeout = timeout
# -> 3037         super(QueryJob, self)._blocking_poll(timeout=timeout)
#    3038
#    3039     @staticmethod
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in _blocking_poll(self, timeout)
#      99
#     100         try:
# --> 101             retry_(self._done_or_raise)()
#     102         except exceptions.RetryError:
#     103             raise concurrent.futures.TimeoutError(
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     284                 sleep_generator,
#     285                 self._deadline,
# --> 286                 on_error=on_error,
#     287             )
#     288
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     182     for sleep in sleep_generator:
#     183         try:
# --> 184             return target()
#     185
#     186         # pylint: disable=broad-except
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in _done_or_raise(self)
#      78     def _done_or_raise(self):
#      79         """Check if the future is done and raise if it's not."""
# ---> 80         if not self.done():
#      81             raise _OperationNotComplete()
#      82
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in done(self, retry)
#    3022                 project=self.project,
#    3023                 timeout_ms=timeout_ms,
# -> 3024                 location=self.location,
#    3025             )
#    3026
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _get_query_results(self, job_id, retry, project, timeout_ms, location)
#    1110         # QueryJob.result()). So we don't need to poll here.
#    1111         resource = self._call_api(
# -> 1112             retry, method="GET", path=path, query_params=extra_params
#    1113         )
#    1114         return _QueryResults.from_api_repr(resource)
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     485         if retry:
#     486             call = retry(call)
# --> 487         return call()
#     488
#     489     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     284                 sleep_generator,
#     285                 self._deadline,
# --> 286                 on_error=on_error,
#     287             )
#     288
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     182     for sleep in sleep_generator:
#     183         try:
# --> 184             return target()
#     185
#     186         # pylint: disable=broad-except
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     415             headers=headers,
#     416             target_object=_target_object,
# --> 417             timeout=timeout,
#     418         )
#     419
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/_http.py in _make_request(self, method, url, data, content_type, headers, target_object, timeout)
#     273
#     274         return self._do_request(
# --> 275             method, url, headers, data, target_object, timeout=timeout
#     276         )
#     277
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/_http.py in _do_request(self, method, url, headers, data, target_object, timeout)
#     311         """
#     312         return self.http.request(
# --> 313             url=url, method=method, headers=headers, data=data, timeout=timeout
#     314         )
#     315
#
# ~/anaconda3/lib/python3.7/site-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, timeout, **kwargs)
#     285                 headers=request_headers,
#     286                 timeout=timeout,
# --> 287                 **kwargs
#     288             )
#     289         timeout = guard.remaining_timeout
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
# Clean the Dataset
# Load the .csv as Pandas Dataframe
import pandas as pd
chicago_crime = pd.read_csv("chicago_crime.csv")

# Change datetime to date
import datetime
from pandas import Series, DataFrame

s = chicago_crime['date'].str.split(' ').apply(Series, 1)
s.name = 'date'
del s[1]
del chicago_crime['date']
chicago_crime = chicago_crime.join(s)

# Name the date column
chicago_crime.columns = ['Unnamed: 0','unique_key','case_number','block','iucr','primary_type','description','location_description','arrest','domestic','beat','district','ward','community_area','fbi_code','x_coordinate','y_coordinate','year','updated_on','latitude','longitude','location','date']
del chicago_crime['Unnamed: 0']

# Export to .csv
chicago_crime.to_csv('chicago_crime.csv', sep=',')

# %%
chicago_crime
# Out:
#         unique_key case_number                      block  iucr  \
# 0         11736749    JC323564        133XX S PRAIRIE AVE  502R
# 1         11742960    JC331059         023XX S NORMAL AVE  0326
# 2         11744041    JC332346         054XX N NEENAH AVE  1305
# 3         11755670    JC346268      058XX N NORTHWEST HWY  0281
# 4         11815598    JC417697         062XX S CICERO AVE  0470
# 215862               OTHER OFFENSE                     TELEPHONE THREAT
# 215863               OTHER OFFENSE                     TELEPHONE THREAT
# 215864               OTHER OFFENSE                     TELEPHONE THREAT
# 215865               OTHER OFFENSE                     TELEPHONE THREAT
# 215866               OTHER OFFENSE              HARASSMENT BY TELEPHONE
# 215867               OTHER OFFENSE              HARASSMENT BY TELEPHONE
# 215868               OTHER OFFENSE          VIOLATE ORDER OF PROTECTION
# 215869               OTHER OFFENSE          VIOLATE ORDER OF PROTECTION
# 215870               OTHER OFFENSE                OTHER VEHICLE OFFENSE
#
#                    location_description  arrest  domestic  beat  ...  \
# 0                                STREET    True     False   533  ...
# 1                                STREET   False     False   914  ...
# 2                             RESIDENCE   False     False  1613  ...
# 3          NURSING HOME/RETIREMENT HOME    True     False  1611  ...
# 4        AIRPORT EXTERIOR - SECURE AREA   False     False   813  ...
# 5                                STREET    True     False   512  ...
# 6                                STREET   False     False   413  ...
# 7                                STREET    True     False   432  ...
# 8                             RESIDENCE   False     False  1611  ...
# 9                             RESIDENCE   False     False   433  ...
# 10       PARKING LOT/GARAGE(NON.RESID.)    True     False   815  ...
# 11                               STREET   False     False  1711  ...
# 12                            RESIDENCE   False     False  1611  ...
# 13                            RESIDENCE   False     False  2213  ...
# 14                   SMALL RETAIL STORE   False     False  1711  ...
# 15      POLICE FACILITY/VEH PARKING LOT    True     False  1623  ...
# 16                               STREET    True     False   511  ...
# 17                            RESIDENCE   False     False   912  ...
# 18          AUTO / BOAT / RV DEALERSHIP   False     False  1611  ...
# 19                               STREET    True     False   512  ...
# 20                                  NaN   False     False   411  ...
# 21                               STREET    True     False   512  ...
# 22              RESIDENCE PORCH/HALLWAY    True     False  2211  ...
# 23                               STREET    True     False   413  ...
# 24                                OTHER   False     False   821  ...
# 25                            RESIDENCE   False     False  1621  ...
# 26       PARKING LOT/GARAGE(NON.RESID.)   False     False   815  ...
# 27                                OTHER   False     False   925  ...
# 28                               STREET   False     False  1623  ...
# 29                            RESIDENCE   False     False  1611  ...
# ...                                 ...     ...       ...   ...  ...
# 215841                           STREET   False     False  2433  ...
# 215842                        RESIDENCE   False     False  2012  ...
# 215843    RESIDENTIAL YARD (FRONT/BACK)   False     False  2433  ...
# 215844                           STREET   False     False  2013  ...
# 215845                           STREET   False     False  2013  ...
# 215846                           STREET   False     False  2013  ...
# 215847               GROCERY FOOD STORE    True     False  2023  ...
# 215848               GROCERY FOOD STORE    True     False  2023  ...
# 215849                CONSTRUCTION SITE   False     False  2012  ...
# 215850                       RESTAURANT    True     False  2022  ...
# 215851                        APARTMENT   False     False  2023  ...
# 215852               SMALL RETAIL STORE    True     False  2433  ...
# 215853      CTA GARAGE / OTHER PROPERTY   False     False  2022  ...
# 215854          RESIDENCE PORCH/HALLWAY   False     False  2433  ...
# 215855               GROCERY FOOD STORE    True     False  2023  ...
# 215856         SCHOOL, PUBLIC, BUILDING   False     False  2013  ...
# 215857                            ALLEY    True     False  2023  ...
# 215858                         SIDEWALK    True     False  2023  ...
# 215859                           STREET    True     False  2433  ...
# 215860                        APARTMENT   False     False  2433  ...
# 215844  (41.981754909, -87.662800025)  2019-04-24
# 215845  (41.990152828, -87.670002502)  2019-05-28
# 215846  (41.983580118, -87.662854434)  2019-06-09
# 215847  (41.976851852, -87.654999693)  2019-07-01
# 215848  (41.976851852, -87.654999693)  2019-02-09
# 215849  (41.985322251, -87.669865064)  2019-07-11
# 215850  (41.983650773, -87.658520968)  2019-06-03
# 215851  (41.982588378, -87.657987846)  2019-12-31
# 215852  (41.993892087, -87.660388215)  2019-02-27
# 215853  (41.986261826, -87.660148577)  2019-07-01
# 215854  (41.995200573, -87.661709798)  2019-07-24
# 215855  (41.978991238, -87.659941972)  2019-04-10
# 215856  (41.989243623, -87.665119726)  2019-01-16
# 215857  (41.980634157, -87.656529996)  2019-10-22
# 215858  (41.983649153, -87.658712242)  2019-09-26
# 215859  (41.993550667, -87.658324436)  2019-05-09
# 215860  (41.992971629, -87.674858378)  2019-12-04
# 215861  (41.977225127, -87.655010442)  2019-08-17
# 215862  (41.985999837, -87.655266727)  2019-06-07
# 215863  (41.977225127, -87.655010442)  2019-02-01
# 215864  (41.985087883, -87.671574145)  2019-04-16
# 215865  (41.986392486, -87.656700734)  2019-11-24
# 215866  (41.997305593, -87.666455417)  2019-09-01
# 215867  (41.990344952, -87.670007864)  2019-05-23
# 215868  (41.982742067, -87.656592266)  2019-10-13
# 215869   (41.980017106, -87.65706246)  2019-09-23
# 215870  (41.988220457, -87.658156374)  2019-08-19
#
# [215871 rows x 22 columns]

# %%
# Encode Type of Incident to Numbers
from sklearn import preprocessing as pr
 
chicago_crime = chicago_crime.drop(columns = ['location','iucr','beat','x_coordinate','y_coordinate','updated_on'], axis = 1)

# %%
# New DataFrame

chicago_crime.head()
# Out:
#    unique_key case_number                  block            primary_type  \
# 0    11736749    JC323564    133XX S PRAIRIE AVE           OTHER OFFENSE
# 1    11742960    JC331059     023XX S NORMAL AVE                 ROBBERY
# 2    11744041    JC332346     054XX N NEENAH AVE         CRIMINAL DAMAGE
# 3    11755670    JC346268  058XX N NORTHWEST HWY     CRIM SEXUAL ASSAULT
# 4    11815598    JC417697     062XX S CICERO AVE  PUBLIC PEACE VIOLATION
#
#                       description            location_description  arrest  \
# 0       VEHICLE TITLE/REG OFFENSE                          STREET    True
# 1  AGGRAVATED VEHICULAR HIJACKING                          STREET   False
# 2             CRIMINAL DEFACEMENT                       RESIDENCE   False
# 3                  NON-AGGRAVATED    NURSING HOME/RETIREMENT HOME    True
# 4                RECKLESS CONDUCT  AIRPORT EXTERIOR - SECURE AREA   False
#
#    domestic  district  ward  community_area fbi_code  year   latitude  \
# 0     False         5   9.0            54.0       26  2019  41.652934
# 1     False         9  25.0            34.0       03  2019  41.849609
# 2     False        16  45.0            10.0       14  2019  41.979703
# 3     False        16  41.0            10.0       02  2019  41.987332
# 4     False         8  23.0            64.0       24  2019  41.779260
#
#    longitude        date
# 0 -87.615626  2019-06-26
# 1 -87.640604  2019-07-02
# 2 -87.790217  2019-07-02
# 3 -87.790163  2019-07-12
# 4 -87.742321  2019-09-02

# %%
#Export to .csv
chicago_crime.to_csv('chicago_crime_clean.csv', sep=',')
